# %%
import sys  # Add core library to the path for development (in production it will be available without this)

sys.path.append("./src/open_aoi_core")

# %%
from sqlalchemy.orm import Session
from open_aoi_core.models import engine
from open_aoi_core.controllers.defect_type import DefectTypeController

# %%
session = Session(engine)
controller = DefectTypeController(session)

# %%
print(controller.list())
# Out:
# [<open_aoi_core.models.DefectTypeModel object at 0x7fd2c5d1f7f0>, <open_aoi_core.models.DefectTypeModel object at 0x7fd2c5d1f280>, <open_aoi_core.models.DefectTypeModel object at 0x7fd2c5d1f8b0>]
