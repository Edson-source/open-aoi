# %%
import sys  # Add core library to the path for development (in production it will be available without this)

sys.path.append("./src/open_aoi_core")

# %%
from open_aoi_core.mixins import MinioBasedMixin
from open_aoi_core.exceptions import ConnectionFailedException

# %%
class MinioBasedClient(MinioBasedMixin):
    pass

client = MinioBasedClient()

# %%
try:
    client.test_minio_connection()
except ConnectionFailedException:
    print("Minio is not available")
